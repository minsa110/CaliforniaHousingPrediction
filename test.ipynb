# %%
import micropip
micropip.install('pandas')
# Out:
# <Task pending name='Task-40' coro=<_PackageManager.install() running at /lib/python3.9/site-packages/micropip/micropip.py:170>>

# %%
import pandas as pd

# %%
import sys
print(sys.version)
# Out:
# 3.9.5 (default, Sep 16 2021, 11:22:45)
# [Clang 13.0.0 (/b/s/w/ir/cache/git/chromium.googlesource.com-external-github.co

# %%
from pyodide.http import pyfetch
import json
response = await pyfetch('https://httpbin.org/json')
out = await response.json()
print(out)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 from pyodide.http import pyfetch
#       2 import json
#       3 response = await pyfetch('https://httpbin.org/json')
#
# ModuleNotFoundError: No module named 'pyodide.http'

# %%
# set up local HTTP server (e.g. python3 -m http.server 8070)
# housing = pd.read_csv("http://localhost:8070/data/housing.csv")

# %%
import numpy as np
from string import ascii_uppercase as letters

df = pd.DataFrame(np.random.randint(0, 100, size=(100, len(letters))), columns=list(letters))
df
# Out:
#      A   B   C   D   E   F   G   H   I   J  ...   Q   R   S   T   U   V   W  \
# 0   99  34  26  87  57  74  43   6  47  37  ...  65  75  70  44  54  43  98
# 1   12  22  85  72  45  40   1  41  10  53  ...  60  39  77  27  76  94  33
# 2   31  82  14  88  54  55  47  80  89  41  ...  16  50  25  47  19  98  49
# 3   90  27  98  95  43  47  77  92  25  70  ...  42  25  80  25  98  41  53
# 4    4   4  98  23  52  48  25  64  75  69  ...  62  50  66  62  43  68  46
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..
# 95  38   5  57  48  89  94  86  31  82  41  ...  61  40  13   6  98  66  54
# 96  16  40  67  87  49  44  17   0  28  55  ...  61   4  31  49  94  73  84
# 97  23  18  14  72  43  76   0  79  23  64  ...  73  91   9  19  48  45  14
# 98  28  54  93  84  21  12  90  77  77  96  ...  20  31  92  20  39  26  98
# 99  56  13  42  71  56  16  40  39  26  98  ...  87  94  46  16  39  24   5
#
#      X   Y   Z
# 0   25  77  60
# 1   47   5  99
# ...
